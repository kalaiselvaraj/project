# %%
import pandas as pd
df=pd.read_csv("data.csv")
df.head(10)
# Out:
#   EmployeeID         EmployeeName Department  Age  Gender  YearsExperience  \
# 0      E0001           Lisa Haney    Finance   32  Female               10
# 1      E0002  Mitchell Villanueva    Finance   46    Male               15
# 2      E0003         Scott Murray      Sales   50    Male                6
# 3      E0004           Nancy Hill         IT   44    Male                4
# 4      E0005        Brenda Curtis    Finance   38    Male                3
# 5      E0006        Mathew Martin    Finance   36  Female               12
# 6      E0007         Joshua Singh         HR   56    Male               24
# 7      E0008      Ashley Anderson      Sales   58  Female               24
# 8      E0009         Amanda White         IT   60    Male               22
# 9      E0010         David Atkins         IT   37  Female               12
#
#   SalaryBand  MonthlyIncome  JobSatisfaction  WorkLifeBalance Overtime  \
# 0       High         121386                1                4      Yes
# 1     Medium         146399                3                2       No
# 2     Medium          28778                5                2      Yes
# 3       High          81821                4                5       No
# 4     Medium          44775                5                1      Yes
# 5        Low         129936                5                5      Yes
# 6       High         133220                2                4       No
# 7        Low          70810                3                4       No
# 8        Low         101550                2                4       No
# 9     Medium          37165                2                2       No
#
#   Attrition
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9        No

# %%
df.tail(5)
# Out:
#     EmployeeID    EmployeeName  Department  Age  Gender  YearsExperience  \
# 995      E0996  Steven Bentley          HR   40    Male                5
# 996      E0997  Kristin Miller  Operations   33    Male               27
# 997      E0998    Joshua Gibbs     Finance   32    Male               26
# 998      E0999      David Hood     Finance   47  Female                6
# 999      E1000   Sharon Rogers  Operations   41    Male               13
#
#     SalaryBand  MonthlyIncome  JobSatisfaction  WorkLifeBalance Overtime  \
# 995     Medium         117053                5                1      Yes
# 996     Medium          92430                3                2      Yes
# 997        Low          55438                3                5       No
# 998       High          22241                4                2       No
# 999     Medium          51356                4                2       No
#
#     Attrition Total   Average   Grade
# 995       Yes   NaN  29274.75   30000
# 996        No   NaN  23117.00   12000
# 997        No   NaN  13869.50   12000
# 998        No   NaN   5573.50  140000
# 999        No   NaN  12850.75   12000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       1000 non-null   object
#  1   EmployeeName     1000 non-null   object
#  2   Department       1000 non-null   object
#  3   Age              1000 non-null   int64
#  4   Gender           1000 non-null   object
#  5   YearsExperience  1000 non-null   int64
#  6   SalaryBand       1000 non-null   object
#  7   MonthlyIncome    1000 non-null   int64
#  8   JobSatisfaction  1000 non-null   int64
#  9   WorkLifeBalance  1000 non-null   int64
#  10  Overtime         1000 non-null   object
#  11  Attrition        1000 non-null   object
#  12  Total            0 non-null      object
#  13  Average          1000 non-null   float64
#  14  Grade            1000 non-null   object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 117.3+ KB

# %%
df.columns
# Out:
# Index(['EmployeeID', 'EmployeeName', 'Department', 'Age', 'Gender',
#        'YearsExperience', 'SalaryBand', 'MonthlyIncome', 'JobSatisfaction',
#        'WorkLifeBalance', 'Overtime', 'Attrition', 'Total', 'Average',
#        'Grade'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age  YearsExperience  MonthlyIncome  JobSatisfaction  \
# count  1000.000000      1000.000000    1000.000000      1000.000000
# mean     40.303000        15.373000   84849.310000         2.993000
# std      11.512938         9.004496   37738.481694         1.425827
# min      21.000000         0.000000   20003.000000         1.000000
# 25%      30.000000         7.000000   53313.250000         2.000000
# 50%      40.000000        15.500000   82309.500000         3.000000
# 75%      50.000000        23.000000  117405.000000         4.000000
# max      60.000000        30.000000  149931.000000         5.000000
#
#        WorkLifeBalance       Average
# count      1000.000000   1000.000000
# mean          3.060000  21223.916500
# std           1.416477   9434.581741
# min           1.000000   5014.750000
# 25%           2.000000  13339.812500
# 50%           3.000000  20587.875000
# 75%           4.000000  29359.000000
# max           5.000000  37495.750000

# %%
df.isnull().sum()
# Out:
# EmployeeID            0
# EmployeeName          0
# Department            0
# Age                   0
# Gender                0
# YearsExperience       0
# SalaryBand            0
# MonthlyIncome         0
# JobSatisfaction       0
# WorkLifeBalance       0
# Overtime              0
# Attrition             0
# Total              1000
# Average               0
# Grade                 0
# dtype: int64

# %%
employee=['Department','Gender','Age']
df['Total']=df[employee].sum(axis=0)
df[['EmployeeName','Department','Gender','YearsExperience']].tail()
# Out:
#        EmployeeName  Department  Gender  YearsExperience
# 995  Steven Bentley          HR    Male                5
# 996  Kristin Miller  Operations    Male               27
# 997    Joshua Gibbs     Finance    Male               26
# 998      David Hood     Finance  Female                6
# 999   Sharon Rogers  Operations    Male               13

# %%
df['Average']=df[['Age','MonthlyIncome','JobSatisfaction','WorkLifeBalance']].mean(axis=1)
df[['EmployeeName','Average']].head(5)
# Out:
#           EmployeeName   Average
# 0           Lisa Haney  30355.75
# 1  Mitchell Villanueva  36612.50
# 2         Scott Murray   7208.75
# 3           Nancy Hill  20468.50
# 4        Brenda Curtis  11204.75

# %%
def grade(avg):
  if avg>=29000:
    return'30000'
  elif avg>=49000:
    return'40000'
  elif avg>=68687:
    return'70000'
  elif avg>=11765:
    return'12000'
  else:
    return'140000'
df['Grade']=df['Average'].apply(grade)
df[['EmployeeName','Average','Grade']].head(7)
# Out:
#           EmployeeName   Average   Grade
# 0           Lisa Haney  30355.75   30000
# 1  Mitchell Villanueva  36612.50   30000
# 2         Scott Murray   7208.75  140000
# 3           Nancy Hill  20468.50   12000
# 4        Brenda Curtis  11204.75  140000
# 5        Mathew Martin  32495.50   30000
# 6         Joshua Singh  33320.50   30000

# %%
df['MonthlyIncome'].mean()
# Out:
# np.float64(84849.31)

# %%
df['WorkLifeBalance'].max()
# Out:
# 5

# %%
df['WorkLifeBalance'].min()
# Out:
# 1

# %%
df[df['MonthlyIncome']>70000]
# Out:
#     EmployeeID         EmployeeName  Department  Age  Gender  YearsExperience  \
# 0        E0001           Lisa Haney     Finance   32  Female               10
# 1        E0002  Mitchell Villanueva     Finance   46    Male               15
# 3        E0004           Nancy Hill          IT   44    Male                4
# 5        E0006        Mathew Martin     Finance   36  Female               12
# 6        E0007         Joshua Singh          HR   56    Male               24
# ..         ...                  ...         ...  ...     ...              ...
# 989      E0990      Wesley Cantrell  Operations   55    Male               20
# 991      E0992       Jessica Torres       Sales   39    Male                8
# 992      E0993          Amy Roberts     Finance   30  Female                9
# 995      E0996       Steven Bentley          HR   40    Male                5
# 996      E0997       Kristin Miller  Operations   33    Male               27
#
#     SalaryBand  MonthlyIncome  JobSatisfaction  WorkLifeBalance Overtime  \
# 0         High         121386                1                4      Yes
# 1       Medium         146399                3                2       No
# 3         High          81821                4                5       No
# 5          Low         129936                5                5      Yes
# 6         High         133220                2                4       No
# ..         ...            ...              ...              ...      ...
# 989     Medium          79668                4                5       No
# 991     Medium         139020                5                3       No
# 992        Low          81550                4                1       No
# 995     Medium         117053                5                1      Yes
# 996     Medium          92430                3                2      Yes
#
#     Attrition Total   Average  Grade
# 0          No   NaN  30355.75  30000
# 1          No   NaN  36612.50  30000
# 3          No   NaN  20468.50  12000
# 5         Yes   NaN  32495.50  30000
# 6          No   NaN  33320.50  30000
# ..        ...   ...       ...    ...
# 989        No   NaN  19933.00  12000
# 991        No   NaN  34766.75  30000
# 992        No   NaN  20396.25  12000
# 995       Yes   NaN  29274.75  30000
# 996        No   NaN  23117.00  12000
#
# [622 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
MonthlyIncome_avg = df.groupby('EmployeeName')['MonthlyIncome'].mean()
plt.figure(figsize=(15,10))
colors=['pink','yellow','red','blue','gray','green']
MonthlyIncome_avg.head(6).plot(kind='bar',color=colors)
plt.title('Average MonthlyIncome by EmployeeName')
plt.xlabel('EmployeeName')
plt.ylabel('Average MonthlyIncome')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
